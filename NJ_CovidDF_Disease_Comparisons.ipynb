# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
covid_data_csv = Path("Provisional_COVID-19_Deaths_by_Sex_and_Age_20240328.csv")
covid_data_df = pd.read_csv(covid_data_csv)

# %%
covid_data_df
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 0       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 2       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 3       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 4       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# ...            ...         ...         ...       ...     ...    ...
# 137695  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 137696  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 137697  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 137698  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 137699  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#                 State        Sex          Age Group  COVID-19 Deaths  \
# 0       United States  All Sexes           All Ages        1146774.0
# ...

# %%
columns = ["Data As Of", "Start Date", "End Date",	"Group", "Year", "Month", "State", "Sex", "Age Group",
           "COVID-19 Deaths", "Total Deaths", "Pneumonia Deaths", "Pneumonia and COVID-19 Deaths", "Influenza Deaths",
           "Pneumonia, Influenza, or COVID-19 Deaths"]
covid_nj_df = covid_data_df.loc[covid_data_df["State"] == "New Jersey", columns]

# %%
covid_nj_df
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month  \
# 1581   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1582   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1583   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1584   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1585   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# ...           ...         ...         ...       ...     ...    ...
# 87205  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 87206  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 87207  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 87208  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 87209  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#             State        Sex          Age Group  COVID-19 Deaths  \
# 1581   New Jersey  All Sexes           All Ages          35691.0
# ...

# %%
len(covid_nj_df)
# Out:
# 2550

# %%
by_total_df = covid_nj_df.loc[covid_nj_df['Group']=='By Total',:]
by_total_df
# Out:
#       Data As Of  Start Date    End Date     Group  Year  Month       State  \
# 1581  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1582  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1583  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1584  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1585  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1586  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1587  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1588  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1589  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1590  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1591  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# ...

# %%
by_total_df.columns
# Out:
# Index(['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
#        'State', 'Sex', 'Age Group', 'COVID-19 Deaths', 'Total Deaths',
#        'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths', 'Influenza Deaths',
#        'Pneumonia, Influenza, or COVID-19 Deaths'],
#       dtype='object')

# %%
diseases = ['Pneumonia, Influenza, \nor COVID-19 Deaths','COVID-19 Deaths','Pneumonia Deaths', 'Pneumonia and \nCOVID-19 Deaths', 
            'Influenza Deaths']

all_total = by_total_df.loc[1581,['Pneumonia, Influenza, or COVID-19 Deaths','COVID-19 Deaths', 'Pneumonia Deaths', 
                                  'Pneumonia and COVID-19 Deaths', 'Influenza Deaths']]
all_total
# Out:
# Pneumonia, Influenza, or COVID-19 Deaths    49766.0
# COVID-19 Deaths                             35691.0
# Pneumonia Deaths                            31031.0
# Pneumonia and COVID-19 Deaths               17287.0
# Influenza Deaths                              363.0
# Name: 1581, dtype: object

# %%
plt.bar(diseases, all_total)
plt.xticks(rotation = 70, ha = 'right', rotation_mode = 'anchor')
plt.title('Full Term Total Deaths by Disease')
plt.ylabel("Volume of Death's")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
all_sex_df = by_total_df.loc[by_total_df['Sex'] == 'All Sexes',:]
all_sex_df
# Out:
#       Data As Of  Start Date    End Date     Group  Year  Month       State  \
# 1581  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1582  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1583  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1584  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1585  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1586  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1587  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1588  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1589  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1590  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1591  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# ...

# %%
all_sex_df.columns
# Out:
# Index(['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
#        'State', 'Sex', 'Age Group', 'COVID-19 Deaths', 'Total Deaths',
#        'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths', 'Influenza Deaths',
#        'Pneumonia, Influenza, or COVID-19 Deaths'],
#       dtype='object')

# %%
all_sex_without_total_df = all_sex_df.loc[1582:1597,:]
all_sex_without_total_df
# Out:
#       Data As Of  Start Date    End Date     Group  Year  Month       State  \
# 1582  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1583  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1584  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1585  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1586  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1587  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1588  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1589  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1590  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1591  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# 1592  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  New Jersey
# ...

# %%
all_sex_without_total_df = all_sex_without_total_df.loc[:,['Data As Of', 'Start Date', 'End Date', 'Group',
                                                           'State', 'Sex', 'Age Group', 'COVID-19 Deaths', 'Total Deaths',
                                                           'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths', 'Influenza Deaths',
                                                           'Pneumonia, Influenza, or COVID-19 Deaths']]
all_sex_without_total_df
# Out:
#       Data As Of  Start Date    End Date     Group       State        Sex  \
# 1582  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1583  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1584  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1585  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1586  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1587  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1588  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1589  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1590  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1591  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1592  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# 1593  09/27/2023  01/01/2020  09/23/2023  By Total  New Jersey  All Sexes
# ...
