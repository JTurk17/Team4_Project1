# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
covid_data_csv = Path("COVID-19_Deaths_by_Sex_and_Age_20240328.csv")
covid_data_df = pd.read_csv(covid_data_csv)

# %%
covid_data_df.head()
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
# 1  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
# 2  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
# 3  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
# 4  09/27/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
#
#          Sex     Age Group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0  All Sexes      All Ages        1146774.0    12303399.0         1162844.0
# 1  All Sexes  Under 1 year            519.0       73213.0            1056.0
# 2  All Sexes    0-17 years           1696.0      130970.0            2961.0
# 3  All Sexes     1-4 years            285.0       14299.0             692.0
# 4  All Sexes    5-14 years            509.0       22008.0             818.0
#
# ...

# %%
columns = ["Data As Of", "Start Date", "End Date",	"Group", "Year", "Month", "State", "Sex", "Age Group",
           "COVID-19 Deaths", "Total Deaths", "Pneumonia Deaths", "Pneumonia and COVID-19 Deaths", "Influenza Deaths",
           "Pneumonia, Influenza, or COVID-19 Deaths"]
covid_nj_df = covid_data_df.loc[covid_data_df["State"] == "New Jersey", columns]

# %%
covid_nj_df
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month  \
# 1581   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1582   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1583   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1584   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1585   09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# ...           ...         ...         ...       ...     ...    ...
# 87205  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 87206  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 87207  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 87208  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 87209  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#             State        Sex          Age Group  COVID-19 Deaths  \
# 1581   New Jersey  All Sexes           All Ages          35691.0
# ...

# %%
columns2 = ["Start Date", "End Date", "State", "Sex", "Age Group", "COVID-19 Deaths", "Total Deaths", "Pneumonia Deaths", "Pneumonia and COVID-19 Deaths", "Influenza Deaths",
           "Pneumonia, Influenza, or COVID-19 Deaths"]
#creating data fram for males
male_df = covid_nj_df.loc[covid_nj_df["Sex"] == "Male", columns2]
male_df
# Out:
#        Start Date    End Date       State   Sex          Age Group  \
# 1598   01/01/2020  09/23/2023  New Jersey  Male           All Ages
# 1599   01/01/2020  09/23/2023  New Jersey  Male       Under 1 year
# 1600   01/01/2020  09/23/2023  New Jersey  Male         0-17 years
# 1601   01/01/2020  09/23/2023  New Jersey  Male          1-4 years
# 1602   01/01/2020  09/23/2023  New Jersey  Male         5-14 years
# ...           ...         ...         ...   ...                ...
# 87188  09/01/2023  09/23/2023  New Jersey  Male        50-64 years
# 87189  09/01/2023  09/23/2023  New Jersey  Male        55-64 years
# 87190  09/01/2023  09/23/2023  New Jersey  Male        65-74 years
# 87191  09/01/2023  09/23/2023  New Jersey  Male        75-84 years
# 87192  09/01/2023  09/23/2023  New Jersey  Male  85 years and over
#
#        COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 1598           19376.0      158472.0           17012.0
# ...

# %%
female_df = covid_nj_df.loc[covid_nj_df["Sex"] == "Female", columns2]
female_df
