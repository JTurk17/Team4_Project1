# %%
#import libraries
import csv
import os
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as mp
from scipy.stats import linregress
from pathlib import Path

# %%
#path of csv files
covid_cleaned_data_path = "Cleaned_Covid_Data.csv"
covid_cleaned_dataframe = pd.read_csv(covid_cleaned_data_path)

covid_cleaned_dataframe.head()
#len(covid_cleaned_dataframe)

covid_data_csv = Path("Cleaned_Covid_Data.csv")
covid_data_df = pd.read_csv(covid_data_csv)

covid_data_csv = Path("Cleaned_Covid_Data.csv")
covid_data_df = pd.read_csv(covid_data_csv)

# %%
#DP

#QUESTIONS TO ANSWER

#What are the notable differences in the distribution of deaths involving COVID-19, pneumonia, and influenza among different months in the year? 
#Is there a trend in death volume based on time of year?

#column for months
months_column = ["January","February","March","April","May","June","July","August","September","October","November","December"]

nj_covid_data = covid_cleaned_dataframe.loc[covid_cleaned_dataframe["State"] == "New Jersey"]
nj_covid_data.head()
# Out:
#       Unnamed: 0  Data As Of  Start Date    End Date     Group  Year  Month  \
# 1149        1581  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
# 1150        1586  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
# 1151        1587  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
# 1152        1588  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
# 1153        1589  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
#
#            State        Sex    Age Group  COVID-19 Deaths  Total Deaths  \
# 1149  New Jersey  All Sexes     All Ages          35691.0      312963.0
# 1150  New Jersey  All Sexes  15-24 years             53.0        2051.0
# 1151  New Jersey  All Sexes  18-29 years            166.0        4079.0
# 1152  New Jersey  All Sexes  25-34 years            287.0        5603.0
# 1153  New Jersey  All Sexes  30-39 years            452.0        7323.0
#
#       Pneumonia Deaths  Pneumonia and COVID-19 Deaths
# 1149           31031.0                        17287.0
# 1150              58.0                           15.0
# 1151             143.0                           65.0
# 1152             243.0                          129.0
# 1153             369.0                          198.0

# %%
#DP

#Doind deaths by month for 2020, so I have to first sort this data by year 2020, and then sum all deaths by month 
nj_covid_data_2020 = nj_covid_data.loc[(nj_covid_data["Year"] == 2020.0) & (nj_covid_data["Month"] > 0) & (nj_covid_data["Age Group"] == 'All Ages') & (nj_covid_data["Sex"] == 'All Sexes')]
nj_covid_data_2020["Month"] = months_column

nj_covid_data_2020 = nj_covid_data_2020[['Month', 'COVID-19 Deaths','Pneumonia Deaths', 'Total Deaths',]]

nj_covid_data_2020.head(12)

nj_covid_data_2020.plot(x="Month", y=["COVID-19 Deaths","Pneumonia Deaths", "Total Deaths"], kind="bar")
plt.ylabel("Number of Deaths")
plt.title("Number of Covid-19 and Total Deaths, 2020")
# Out:
# C:\Users\Darshan Patel\AppData\Local\Temp\ipykernel_4076\2762115328.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nj_covid_data_2020["Month"] = months_column
# Text(0.5, 1.0, 'Number of Covid-19 and Total Deaths, 2020')

# %%
#DP

#Doing deaths by month for 2021, so I have to first sort this data by year 2021, and then sum all deaths by month 

nj_covid_data_2021 = nj_covid_data.loc[(nj_covid_data["Year"] == 2021.0) & (nj_covid_data["Month"] > 0) & (nj_covid_data["Age Group"] == 'All Ages') & (nj_covid_data["Sex"] == 'All Sexes')]
nj_covid_data_2021["Month"] = months_column

nj_covid_data_2021 = nj_covid_data_2021[['Month', 'COVID-19 Deaths','Pneumonia Deaths', 'Total Deaths']]

nj_covid_data_2021.head(12)

nj_covid_data_2021.plot(x="Month", y=["COVID-19 Deaths","Pneumonia Deaths", "Total Deaths"], kind="bar")
plt.ylabel("Number of Deaths")
plt.title("Number of Covid-19 and Total Deaths, 2021")
# Out:
# C:\Users\Darshan Patel\AppData\Local\Temp\ipykernel_4076\293774567.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nj_covid_data_2021["Month"] = months_column
# Text(0.5, 1.0, 'Number of Covid-19 and Total Deaths, 2021')

# %%
#DP

#Doing deaths by month for 2022, so I have to first sort this data by year 2022, and then sum all deaths by month 

nj_covid_data_2022 = nj_covid_data.loc[(nj_covid_data["Year"] == 2022.0) & (nj_covid_data["Month"] > 0) & (nj_covid_data["Age Group"] == 'All Ages') & (nj_covid_data["Sex"] == 'All Sexes')]
nj_covid_data_2022["Month"] = months_column

nj_covid_data_2022 = nj_covid_data_2022[['Month', 'COVID-19 Deaths','Pneumonia Deaths', 'Total Deaths']]

nj_covid_data_2022.head(12)

nj_covid_data_2022.plot(x="Month", y=["COVID-19 Deaths","Pneumonia Deaths", "Total Deaths"], kind="bar")
plt.ylabel("NUmber ofDeaths")
plt.title("Number of Covid-19 and Total Deaths, 2022")
# Out:
# C:\Users\Darshan Patel\AppData\Local\Temp\ipykernel_4076\1564202491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nj_covid_data_2022["Month"] = months_column
# Text(0.5, 1.0, 'Number of Covid-19 and Total Deaths, 2022')

# %%
#DS

#Trimming down the COVID Dataframe
columns = ["Start Date","End Date","Group","Year","State","Sex","Age Group","COVID-19 Deaths"]
covid_data_all_sexes=covid_data_df.loc[covid_data_df["Sex"]=="All Sexes",columns]
covid_data_all_ages=covid_data_all_sexes.loc[covid_data_all_sexes["Age Group"]=="All Ages",columns]

#Making Dataframes with data from New Jersey, New York, Pennsylvania, California, Texas, Florida, and Illinois
covid_nj_df=covid_data_all_ages.loc[covid_data_all_ages["State"]=="New Jersey",columns]
covid_ny_df=covid_data_all_ages.loc[covid_data_all_ages["State"]=="New York",columns]
covid_pa_df=covid_data_all_ages.loc[covid_data_all_ages["State"]=="Pennsylvania",columns]
covid_ca_df=covid_data_all_ages.loc[covid_data_all_ages["State"]=="California",columns]
covid_tx_df=covid_data_all_ages.loc[covid_data_all_ages["State"]=="Texas",columns]
covid_fl_df=covid_data_all_ages.loc[covid_data_all_ages["State"]=="Florida",columns]
covid_wy_df=covid_data_all_ages.loc[covid_data_all_ages["State"]=="Wyoming",columns]
covid_ma_df=covid_data_all_ages.loc[covid_data_all_ages["State"]=="Massachusetts",columns]

covid_nj_df
# Out:
#        Start Date    End Date     Group    Year       State        Sex  \
# 1149   01/01/2020  09/23/2023  By Total     0.0  New Jersey  All Sexes
# 5583   01/01/2020  12/31/2020   By Year  2020.0  New Jersey  All Sexes
# 5621   01/01/2021  12/31/2021   By Year  2021.0  New Jersey  All Sexes
# 5658   01/01/2022  12/31/2022   By Year  2022.0  New Jersey  All Sexes
# 5691   01/01/2023  09/23/2023   By Year  2023.0  New Jersey  All Sexes
# 35129  01/01/2020  01/31/2020  By Month  2020.0  New Jersey  All Sexes
# 35154  02/01/2020  02/29/2020  By Month  2020.0  New Jersey  All Sexes
# 35180  03/01/2020  03/31/2020  By Month  2020.0  New Jersey  All Sexes
# 35214  04/01/2020  04/30/2020  By Month  2020.0  New Jersey  All Sexes
# 35247  05/01/2020  05/31/2020  By Month  2020.0  New Jersey  All Sexes
# 35279  06/01/2020  06/30/2020  By Month  2020.0  New Jersey  All Sexes
# 35304  07/01/2020  07/31/2020  By Month  2020.0  New Jersey  All Sexes
# 35325  08/01/2020  08/31/2020  By Month  2020.0  New Jersey  All Sexes
# 35335  09/01/2020  09/30/2020  By Month  2020.0  New Jersey  All Sexes
# 35358  10/01/2020  10/31/2020  By Month  2020.0  New Jersey  All Sexes
# 35377  11/01/2020  11/30/2020  By Month  2020.0  New Jersey  All Sexes
# 35402  12/01/2020  12/31/2020  By Month  2020.0  New Jersey  All Sexes
# 35432  01/01/2021  01/31/2021  By Month  2021.0  New Jersey  All Sexes
# 35466  02/01/2021  02/28/2021  By Month  2021.0  New Jersey  All Sexes
# 35497  03/01/2021  03/31/2021  By Month  2021.0  New Jersey  All Sexes
# 35523  04/01/2021  04/30/2021  By Month  2021.0  New Jersey  All Sexes
# 35549  05/01/2021  05/31/2021  By Month  2021.0  New Jersey  All Sexes
# 35576  06/01/2021  06/30/2021  By Month  2021.0  New Jersey  All Sexes
# 35591  07/01/2021  07/31/2021  By Month  2021.0  New Jersey  All Sexes
# 35605  08/01/2021  08/31/2021  By Month  2021.0  New Jersey  All Sexes
# 35629  09/01/2021  09/30/2021  By Month  2021.0  New Jersey  All Sexes
# 35655  10/01/2021  10/31/2021  By Month  2021.0  New Jersey  All Sexes
# 35684  11/01/2021  11/30/2021  By Month  2021.0  New Jersey  All Sexes
# 35706  12/01/2021  12/31/2021  By Month  2021.0  New Jersey  All Sexes
# 35733  01/01/2022  01/31/2022  By Month  2022.0  New Jersey  All Sexes
# 35763  02/01/2022  02/28/2022  By Month  2022.0  New Jersey  All Sexes
# 35788  03/01/2022  03/31/2022  By Month  2022.0  New Jersey  All Sexes
# 35810  04/01/2022  04/30/2022  By Month  2022.0  New Jersey  All Sexes
# 35825  05/01/2022  05/31/2022  By Month  2022.0  New Jersey  All Sexes
# 35846  06/01/2022  06/30/2022  By Month  2022.0  New Jersey  All Sexes
# 35861  07/01/2022  07/31/2022  By Month  2022.0  New Jersey  All Sexes
# 35878  08/01/2022  08/31/2022  By Month  2022.0  New Jersey  All Sexes
# 35896  09/01/2022  09/30/2022  By Month  2022.0  New Jersey  All Sexes
# 35912  10/01/2022  10/31/2022  By Month  2022.0  New Jersey  All Sexes
# 35929  11/01/2022  11/30/2022  By Month  2022.0  New Jersey  All Sexes
# 35946  12/01/2022  12/31/2022  By Month  2022.0  New Jersey  All Sexes
# 35961  01/01/2023  01/31/2023  By Month  2023.0  New Jersey  All Sexes
# 35981  02/01/2023  02/28/2023  By Month  2023.0  New Jersey  All Sexes
# 36001  03/01/2023  03/31/2023  By Month  2023.0  New Jersey  All Sexes
# 36014  04/01/2023  04/30/2023  By Month  2023.0  New Jersey  All Sexes
# 36024  05/01/2023  05/31/2023  By Month  2023.0  New Jersey  All Sexes
# 36034  06/01/2023  06/30/2023  By Month  2023.0  New Jersey  All Sexes
# 36039  07/01/2023  07/31/2023  By Month  2023.0  New Jersey  All Sexes
# 36049  08/01/2023  08/31/2023  By Month  2023.0  New Jersey  All Sexes
# 36064  09/01/2023  09/23/2023  By Month  2023.0  New Jersey  All Sexes
#
#       Age Group  COVID-19 Deaths
# 1149   All Ages          35691.0
# 5583   All Ages          18164.0
# 5621   All Ages           9605.0
# 5658   All Ages           6571.0
# 5691   All Ages           1351.0
# 35129  All Ages              0.0
# 35154  All Ages              0.0
# 35180  All Ages            701.0
# 35214  All Ages           9010.0
# 35247  All Ages           3358.0
# 35279  All Ages            841.0
# 35304  All Ages            330.0
# 35325  All Ages            168.0
# 35335  All Ages            144.0
# 35358  All Ages            280.0
# 35377  All Ages            944.0
# 35402  All Ages           2388.0
# 35432  All Ages           2482.0
# 35466  All Ages           1453.0
# 35497  All Ages           1045.0
# 35523  All Ages           1037.0
# 35549  All Ages            526.0
# 35576  All Ages            162.0
# 35591  All Ages            132.0
# 35605  All Ages            360.0
# 35629  All Ages            576.0
# 35655  All Ages            530.0
# 35684  All Ages            391.0
# 35706  All Ages            911.0
# 35733  All Ages           3052.0
# 35763  All Ages            867.0
# 35788  All Ages            219.0
# 35810  All Ages            161.0
# 35825  All Ages            282.0
# 35846  All Ages            223.0
# 35861  All Ages            277.0
# 35878  All Ages            265.0
# 35896  All Ages            234.0
# 35912  All Ages            281.0
# 35929  All Ages            299.0
# 35946  All Ages            411.0
# 35961  All Ages            446.0
# 35981  All Ages            289.0
# 36001  All Ages            183.0
# 36014  All Ages             92.0
# 36024  All Ages             72.0
# 36034  All Ages             48.0
# 36039  All Ages             54.0
# 36049  All Ages             79.0
# 36064  All Ages             88.0

# %%
#DS

#State population estimates in 2020
nj_2020_pop=9272392
ny_2020_pop=20104710
pa_2020_pop=12995477
ca_2020_pop=39503200
tx_2020_pop=29234361
fl_2020_pop=21591299
wy_2020_pop=577664
ma_2020_pop=6997713
#Making Dataframes using all time data
covid_nj_alltime=covid_nj_df.loc[covid_nj_df["Group"]=="By Total",columns]
covid_ny_alltime=covid_ny_df.loc[covid_ny_df["Group"]=="By Total",columns]
covid_pa_alltime=covid_pa_df.loc[covid_pa_df["Group"]=="By Total",columns]
covid_ca_alltime=covid_ca_df.loc[covid_ca_df["Group"]=="By Total",columns]
covid_tx_alltime=covid_tx_df.loc[covid_tx_df["Group"]=="By Total",columns]
covid_fl_alltime=covid_fl_df.loc[covid_fl_df["Group"]=="By Total",columns]
covid_wy_alltime=covid_wy_df.loc[covid_wy_df["Group"]=="By Total",columns]
covid_ma_alltime=covid_ma_df.loc[covid_ma_df["Group"]=="By Total",columns]

#Bar graph showing all time data per state
states=[(covid_nj_alltime.iloc[0,4]),(covid_ny_alltime.iloc[0,4]),(covid_pa_alltime.iloc[0,4]),(covid_ca_alltime.iloc[0,4]),
              (covid_tx_alltime.iloc[0,4]),(covid_fl_alltime.iloc[0,4]),(covid_wy_alltime.iloc[0,4]),(covid_ma_alltime.iloc[0,4])]

covid_alltime_deaths=[(covid_nj_alltime.iloc[0,7]),(covid_ny_alltime.iloc[0,7]),(covid_pa_alltime.iloc[0,7]),(covid_ca_alltime.iloc[0,7]),
              (covid_tx_alltime.iloc[0,7]),(covid_fl_alltime.iloc[0,7]),(covid_wy_alltime.iloc[0,7]),(covid_ma_alltime.iloc[0,7])]

covid_alltime_per_capita=[(covid_nj_alltime.iloc[0,7])/nj_2020_pop,(covid_ny_alltime.iloc[0,7])/ny_2020_pop,
              (covid_pa_alltime.iloc[0,7])/pa_2020_pop,(covid_ca_alltime.iloc[0,7])/ca_2020_pop,
              (covid_tx_alltime.iloc[0,7])/tx_2020_pop,(covid_fl_alltime.iloc[0,7])/fl_2020_pop,
              (covid_wy_alltime.iloc[0,7])/wy_2020_pop,(covid_ma_alltime.iloc[0,7])/ma_2020_pop]

plt.bar(states,covid_alltime_deaths)
plt.xticks(rotation="vertical")
plt.title("Total COVID Deaths 2020-2023")
plt.ylabel("Total Deaths")
plt.show()
plt.bar(states,covid_alltime_per_capita,color="g")
plt.xticks(rotation="vertical")
plt.title("COVID Deaths per Capita 2020-2023")
plt.ylabel("Deaths per Capita")
plt.show()

# %%
#DS

#Making Dataframes using yearly data
covid_nj_year=covid_nj_df.loc[covid_nj_df["Group"]=="By Year",columns]
covid_ny_year=covid_ny_df.loc[covid_ny_df["Group"]=="By Year",columns]
covid_pa_year=covid_pa_df.loc[covid_pa_df["Group"]=="By Year",columns]
covid_ca_year=covid_ca_df.loc[covid_ca_df["Group"]=="By Year",columns]
covid_tx_year=covid_tx_df.loc[covid_tx_df["Group"]=="By Year",columns]
covid_fl_year=covid_fl_df.loc[covid_fl_df["Group"]=="By Year",columns]
covid_wy_year=covid_wy_df.loc[covid_wy_df["Group"]=="By Year",columns]
covid_ma_year=covid_ma_df.loc[covid_ma_df["Group"]=="By Year",columns]

#Calculating deaths per capita per state Dataframe

covid_nj_year_percapita=[]
covid_ny_year_percapita=[]
covid_pa_year_percapita=[]
covid_ca_year_percapita=[]
covid_tx_year_percapita=[]
covid_fl_year_percapita=[]
covid_wy_year_percapita=[]
covid_ma_year_percapita=[]

for index,row in covid_nj_year.iterrows():
    covid_nj_year_percapita.append(row["COVID-19 Deaths"]/nj_2020_pop)

for index,row in covid_ny_year.iterrows():
    covid_ny_year_percapita.append(row["COVID-19 Deaths"]/ny_2020_pop)

for index,row in covid_pa_year.iterrows():
    covid_pa_year_percapita.append(row["COVID-19 Deaths"]/pa_2020_pop)

for index,row in covid_ca_year.iterrows():
    covid_ca_year_percapita.append(row["COVID-19 Deaths"]/ca_2020_pop)
    
for index,row in covid_tx_year.iterrows():
    covid_tx_year_percapita.append(row["COVID-19 Deaths"]/tx_2020_pop)

for index,row in covid_fl_year.iterrows():
    covid_fl_year_percapita.append(row["COVID-19 Deaths"]/fl_2020_pop)

for index,row in covid_wy_year.iterrows():
    covid_wy_year_percapita.append(row["COVID-19 Deaths"]/wy_2020_pop)

for index,row in covid_ma_year.iterrows():
    covid_ma_year_percapita.append(row["COVID-19 Deaths"]/ma_2020_pop)
#Constructing the line graph
years=[]
for index,row in covid_nj_year.iterrows():
    years.append(int(row["Year"]))

tick_locations=[value for value in years]

nj_line,=plt.plot(years,covid_nj_year_percapita,label="New Jersey")
ny_line,=plt.plot(years,covid_ny_year_percapita,label="New York")
pa_line,=plt.plot(years,covid_pa_year_percapita,label="Pennsylvania")
ca_line,=plt.plot(years,covid_ca_year_percapita,label="California")
tx_line,=plt.plot(years,covid_tx_year_percapita,label="Texas")
fl_line,=plt.plot(years,covid_fl_year_percapita,label="Florida")
wy_line,=plt.plot(years,covid_wy_year_percapita,label="Wyoming")
ma_line,=plt.plot(years,covid_ma_year_percapita,label="Massachusetts")
plt.xticks(tick_locations,years)
plt.title("COVID Deaths per Capita 2020-2023")
plt.ylabel("Deaths per Capita")
plt.legend(handles=[nj_line,ny_line,pa_line,ca_line,tx_line,fl_line,wy_line,ma_line])
plt.rcParams["figure.figsize"]=(10,8)
plt.grid()
plt.show()

# %%
#KK

columns = ["Data As Of", "Start Date", "End Date",	"Group", "Year", "Month", "State", "Sex", "Age Group",
           "COVID-19 Deaths", "Total Deaths", "Pneumonia Deaths", "Pneumonia and COVID-19 Deaths"]
covid_nj_df = covid_data_df.loc[covid_data_df["State"] == "New Jersey", columns]
covid_nj_df
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month  \
# 1149   09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 1150   09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 1151   09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 1152   09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 1153   09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# ...           ...         ...         ...       ...     ...    ...
# 36072  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 36073  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 36074  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 36075  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 36076  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#             State        Sex    Age Group  COVID-19 Deaths  Total Deaths  \
# 1149   New Jersey  All Sexes     All Ages          35691.0      312963.0
# 1150   New Jersey  All Sexes  15-24 years             53.0        2051.0
# 1151   New Jersey  All Sexes  18-29 years            166.0        4079.0
# 1152   New Jersey  All Sexes  25-34 years            287.0        5603.0
# 1153   New Jersey  All Sexes  30-39 years            452.0        7323.0
# ...           ...        ...          ...              ...           ...
# 36072  New Jersey       Male  15-24 years              0.0          10.0
# 36073  New Jersey     Female     All Ages             44.0        1824.0
# 36074  New Jersey     Female   5-14 years              0.0           0.0
# 36075  New Jersey     Female  18-29 years              0.0          14.0
# 36076  New Jersey     Female  25-34 years              0.0          14.0
#
#        Pneumonia Deaths  Pneumonia and COVID-19 Deaths
# 1149            31031.0                        17287.0
# 1150               58.0                           15.0
# 1151              143.0                           65.0
# 1152              243.0                          129.0
# 1153              369.0                          198.0
# ...                 ...                            ...
# 36072               0.0                            0.0
# 36073              96.0                           16.0
# 36074               0.0                            0.0
# 36075               0.0                            0.0
# 36076               0.0                            0.0
#
# [1114 rows x 13 columns]

# %%
#KK

columns2 = ["Start Date", "End Date", "State", "Sex","Group", "Age Group", "Year", "Month", "COVID-19 Deaths",
            "Pneumonia Deaths", "Pneumonia and COVID-19 Deaths"]
#creating data fram for males
male_df = covid_nj_df.loc[covid_nj_df["Sex"] == "Male", columns2]
male_df
# Out:
#        Start Date    End Date       State   Sex     Group    Age Group  \
# 1162   01/01/2020  09/23/2023  New Jersey  Male  By Total     All Ages
# 1163   01/01/2020  09/23/2023  New Jersey  Male  By Total  15-24 years
# 1164   01/01/2020  09/23/2023  New Jersey  Male  By Total  18-29 years
# 1165   01/01/2020  09/23/2023  New Jersey  Male  By Total  25-34 years
# 1166   01/01/2020  09/23/2023  New Jersey  Male  By Total  30-39 years
# ...           ...         ...         ...   ...       ...          ...
# 36059  08/01/2023  08/31/2023  New Jersey  Male  By Month  25-34 years
# 36060  08/01/2023  08/31/2023  New Jersey  Male  By Month  30-39 years
# 36070  09/01/2023  09/23/2023  New Jersey  Male  By Month     All Ages
# 36071  09/01/2023  09/23/2023  New Jersey  Male  By Month   0-17 years
# 36072  09/01/2023  09/23/2023  New Jersey  Male  By Month  15-24 years
#
#          Year  Month  COVID-19 Deaths  Pneumonia Deaths  \
# 1162      0.0    0.0          19376.0           17012.0
# 1163      0.0    0.0             35.0              45.0
# 1164      0.0    0.0            108.0              92.0
# 1165      0.0    0.0            190.0             149.0
# 1166      0.0    0.0            300.0             229.0
# ...       ...    ...              ...               ...
# 36059  2023.0    8.0              0.0               0.0
# 36060  2023.0    8.0              0.0               0.0
# 36070  2023.0    9.0             44.0             103.0
# 36071  2023.0    9.0              0.0               0.0
# 36072  2023.0    9.0              0.0               0.0
#
#        Pneumonia and COVID-19 Deaths
# 1162                          9677.0
# 1163                            10.0
# 1164                            43.0
# 1165                            91.0
# 1166                           135.0
# ...                              ...
# 36059                            0.0
# 36060                            0.0
# 36070                           17.0
# 36071                            0.0
# 36072                            0.0
#
# [375 rows x 11 columns]

# %%
#KK

female_df = covid_nj_df.loc[covid_nj_df["Sex"] == "Female", columns2]
female_df
# Out:
#        Start Date    End Date       State     Sex     Group    Age Group  \
# 1175   01/01/2020  09/23/2023  New Jersey  Female  By Total     All Ages
# 1176   01/01/2020  09/23/2023  New Jersey  Female  By Total  18-29 years
# 1177   01/01/2020  09/23/2023  New Jersey  Female  By Total  25-34 years
# 1178   01/01/2020  09/23/2023  New Jersey  Female  By Total  30-39 years
# 1179   01/01/2020  09/23/2023  New Jersey  Female  By Total  35-44 years
# ...           ...         ...         ...     ...       ...          ...
# 36063  08/01/2023  08/31/2023  New Jersey  Female  By Month   0-17 years
# 36073  09/01/2023  09/23/2023  New Jersey  Female  By Month     All Ages
# 36074  09/01/2023  09/23/2023  New Jersey  Female  By Month   5-14 years
# 36075  09/01/2023  09/23/2023  New Jersey  Female  By Month  18-29 years
# 36076  09/01/2023  09/23/2023  New Jersey  Female  By Month  25-34 years
#
#          Year  Month  COVID-19 Deaths  Pneumonia Deaths  \
# 1175      0.0    0.0          16315.0           14019.0
# 1176      0.0    0.0             58.0              51.0
# 1177      0.0    0.0             97.0              94.0
# 1178      0.0    0.0            152.0             140.0
# 1179      0.0    0.0            224.0             194.0
# ...       ...    ...              ...               ...
# 36063  2023.0    8.0              0.0               0.0
# 36073  2023.0    9.0             44.0              96.0
# 36074  2023.0    9.0              0.0               0.0
# 36075  2023.0    9.0              0.0               0.0
# 36076  2023.0    9.0              0.0               0.0
#
#        Pneumonia and COVID-19 Deaths
# 1175                          7610.0
# 1176                            22.0
# 1177                            38.0
# 1178                            63.0
# 1179                           109.0
# ...                              ...
# 36063                            0.0
# 36073                           16.0
# 36074                            0.0
# 36075                            0.0
# 36076                            0.0
#
# [340 rows x 11 columns]

# %%
#KK

total_mcovid_deaths = pd.DataFrame(male_df.loc[male_df['Age Group'] == "All Ages",:])
total_mcovid_deaths.reset_index(inplace = True)

total_mcovid_deaths.head()
# Out:
#    index  Start Date    End Date       State   Sex     Group Age Group  \
# 0   1162  01/01/2020  09/23/2023  New Jersey  Male  By Total  All Ages
# 1   5595  01/01/2020  12/31/2020  New Jersey  Male   By Year  All Ages
# 2   5633  01/01/2021  12/31/2021  New Jersey  Male   By Year  All Ages
# 3   5669  01/01/2022  12/31/2022  New Jersey  Male   By Year  All Ages
# 4   5698  01/01/2023  09/23/2023  New Jersey  Male   By Year  All Ages
#
#      Year  Month  COVID-19 Deaths  Pneumonia Deaths  \
# 0     0.0    0.0          19376.0           17012.0
# 1  2020.0    0.0           9881.0            7353.0
# 2  2021.0    0.0           5340.0            4787.0
# 3  2022.0    0.0           3490.0            3392.0
# 4  2023.0    0.0            665.0            1480.0
#
#    Pneumonia and COVID-19 Deaths
# 0                         9677.0
# 1                         4981.0
# 2                         2871.0
# 3                         1585.0
# 4                          240.0

# %%
#KK

by_year_mdeaths = total_mcovid_deaths.loc[total_mcovid_deaths["Group"] == "By Year", columns2]
by_year_mdeaths ['Year'] = by_year_mdeaths ['Year'].astype(int)

by_year_mdeaths
# Out:
#    Start Date    End Date       State   Sex    Group Age Group  Year  Month  \
# 1  01/01/2020  12/31/2020  New Jersey  Male  By Year  All Ages  2020    0.0
# 2  01/01/2021  12/31/2021  New Jersey  Male  By Year  All Ages  2021    0.0
# 3  01/01/2022  12/31/2022  New Jersey  Male  By Year  All Ages  2022    0.0
# 4  01/01/2023  09/23/2023  New Jersey  Male  By Year  All Ages  2023    0.0
#
#    COVID-19 Deaths  Pneumonia Deaths  Pneumonia and COVID-19 Deaths
# 1           9881.0            7353.0                         4981.0
# 2           5340.0            4787.0                         2871.0
# 3           3490.0            3392.0                         1585.0
# 4            665.0            1480.0                          240.0

# %%
#KK

c = ['maroon', 'olive','lightsteelblue']
covid_male_deaths = by_year_mdeaths.plot.bar(x='Year', y=['Pneumonia and COVID-19 Deaths','Pneumonia Deaths','COVID-19 Deaths'],
                                             figsize=(10,6), alpha=.8, color=c,title ='Male Deaths in NJ')
plt.xlabel('Year')
plt.ylabel('# of Deaths')
plt.savefig("Male Deaths.png")

# %%
#KK

total_fcovid_deaths = pd.DataFrame(female_df.loc[female_df['Age Group'] == "All Ages",:])
total_fcovid_deaths.reset_index(inplace = True)

total_fcovid_deaths
# Out:
#     index  Start Date    End Date       State     Sex     Group Age Group  \
# 0    1175  01/01/2020  09/23/2023  New Jersey  Female  By Total  All Ages
# 1    5609  01/01/2020  12/31/2020  New Jersey  Female   By Year  All Ages
# 2    5645  01/01/2021  12/31/2021  New Jersey  Female   By Year  All Ages
# 3    5681  01/01/2022  12/31/2022  New Jersey  Female   By Year  All Ages
# 4    5705  01/01/2023  09/23/2023  New Jersey  Female   By Year  All Ages
# 5   35145  01/01/2020  01/31/2020  New Jersey  Female  By Month  All Ages
# 6   35170  02/01/2020  02/29/2020  New Jersey  Female  By Month  All Ages
# 7   35205  03/01/2020  03/31/2020  New Jersey  Female  By Month  All Ages
# 8   35237  04/01/2020  04/30/2020  New Jersey  Female  By Month  All Ages
# 9   35271  05/01/2020  05/31/2020  New Jersey  Female  By Month  All Ages
# 10  35297  06/01/2020  06/30/2020  New Jersey  Female  By Month  All Ages
# 11  35319  07/01/2020  07/31/2020  New Jersey  Female  By Month  All Ages
# 12  35333  08/01/2020  08/31/2020  New Jersey  Female  By Month  All Ages
# 13  35352  09/01/2020  09/30/2020  New Jersey  Female  By Month  All Ages
# 14  35372  10/01/2020  10/31/2020  New Jersey  Female  By Month  All Ages
# 15  35396  11/01/2020  11/30/2020  New Jersey  Female  By Month  All Ages
# 16  35421  12/01/2020  12/31/2020  New Jersey  Female  By Month  All Ages
# 17  35454  01/01/2021  01/31/2021  New Jersey  Female  By Month  All Ages
# 18  35487  02/01/2021  02/28/2021  New Jersey  Female  By Month  All Ages
# 19  35514  03/01/2021  03/31/2021  New Jersey  Female  By Month  All Ages
# 20  35542  04/01/2021  04/30/2021  New Jersey  Female  By Month  All Ages
# 21  35567  05/01/2021  05/31/2021  New Jersey  Female  By Month  All Ages
# 22  35589  06/01/2021  06/30/2021  New Jersey  Female  By Month  All Ages
# 23  35602  07/01/2021  07/31/2021  New Jersey  Female  By Month  All Ages
# 24  35622  08/01/2021  08/31/2021  New Jersey  Female  By Month  All Ages
# 25  35648  09/01/2021  09/30/2021  New Jersey  Female  By Month  All Ages
# 26  35675  10/01/2021  10/31/2021  New Jersey  Female  By Month  All Ages
# 27  35699  11/01/2021  11/30/2021  New Jersey  Female  By Month  All Ages
# 28  35727  12/01/2021  12/31/2021  New Jersey  Female  By Month  All Ages
# 29  35753  01/01/2022  01/31/2022  New Jersey  Female  By Month  All Ages
# 30  35781  02/01/2022  02/28/2022  New Jersey  Female  By Month  All Ages
# 31  35801  03/01/2022  03/31/2022  New Jersey  Female  By Month  All Ages
# 32  35821  04/01/2022  04/30/2022  New Jersey  Female  By Month  All Ages
# 33  35839  05/01/2022  05/31/2022  New Jersey  Female  By Month  All Ages
# 34  35855  06/01/2022  06/30/2022  New Jersey  Female  By Month  All Ages
# 35  35872  07/01/2022  07/31/2022  New Jersey  Female  By Month  All Ages
# 36  35890  08/01/2022  08/31/2022  New Jersey  Female  By Month  All Ages
# 37  35905  09/01/2022  09/30/2022  New Jersey  Female  By Month  All Ages
# 38  35922  10/01/2022  10/31/2022  New Jersey  Female  By Month  All Ages
# 39  35940  11/01/2022  11/30/2022  New Jersey  Female  By Month  All Ages
# 40  35957  12/01/2022  12/31/2022  New Jersey  Female  By Month  All Ages
# 41  35974  01/01/2023  01/31/2023  New Jersey  Female  By Month  All Ages
# 42  35996  02/01/2023  02/28/2023  New Jersey  Female  By Month  All Ages
# 43  36009  03/01/2023  03/31/2023  New Jersey  Female  By Month  All Ages
# 44  36031  05/01/2023  05/31/2023  New Jersey  Female  By Month  All Ages
# 45  36061  08/01/2023  08/31/2023  New Jersey  Female  By Month  All Ages
# 46  36073  09/01/2023  09/23/2023  New Jersey  Female  By Month  All Ages
#
#       Year  Month  COVID-19 Deaths  Pneumonia Deaths  \
# 0      0.0    0.0          16315.0           14019.0
# 1   2020.0    0.0           8283.0            5943.0
# 2   2021.0    0.0           4265.0            3851.0
# 3   2022.0    0.0           3081.0            2867.0
# 4   2023.0    0.0            686.0            1358.0
# 5   2020.0    1.0              0.0             191.0
# 6   2020.0    2.0              0.0             165.0
# 7   2020.0    3.0            288.0             421.0
# 8   2020.0    4.0           4110.0            2311.0
# 9   2020.0    5.0           1640.0             916.0
# 10  2020.0    6.0            452.0             328.0
# 11  2020.0    7.0            143.0             157.0
# 12  2020.0    8.0             82.0             160.0
# 13  2020.0    9.0             61.0             130.0
# 14  2020.0   10.0            142.0             172.0
# 15  2020.0   11.0            364.0             322.0
# 16  2020.0   12.0           1001.0             670.0
# 17  2021.0    1.0           1098.0             714.0
# 18  2021.0    2.0            613.0             453.0
# 19  2021.0    3.0            485.0             386.0
# 20  2021.0    4.0            481.0             386.0
# 21  2021.0    5.0            244.0             244.0
# 22  2021.0    6.0             74.0             136.0
# 23  2021.0    7.0             66.0             154.0
# 24  2021.0    8.0            173.0             236.0
# 25  2021.0    9.0            227.0             259.0
# 26  2021.0   10.0            230.0             272.0
# 27  2021.0   11.0            192.0             267.0
# 28  2021.0   12.0            382.0             344.0
# 29  2022.0    1.0           1372.0             816.0
# 30  2022.0    2.0            393.0             306.0
# 31  2022.0    3.0            106.0             165.0
# 32  2022.0    4.0             78.0             153.0
# 33  2022.0    5.0            139.0             165.0
# 34  2022.0    6.0            118.0             146.0
# 35  2022.0    7.0            142.0             178.0
# 36  2022.0    8.0            132.0             146.0
# 37  2022.0    9.0            128.0             163.0
# 38  2022.0   10.0            141.0             180.0
# 39  2022.0   11.0            135.0             206.0
# 40  2022.0   12.0            197.0             243.0
# 41  2023.0    1.0            226.0             211.0
# 42  2023.0    2.0            159.0             182.0
# 43  2023.0    3.0             77.0             164.0
# 44  2023.0    5.0             45.0             149.0
# 45  2023.0    8.0             37.0             138.0
# 46  2023.0    9.0             44.0              96.0
#
#     Pneumonia and COVID-19 Deaths
# 0                          7610.0
# 1                          3865.0
# 2                          2266.0
# 3                          1285.0
# 4                           194.0
# 5                             0.0
# 6                             0.0
# 7                           148.0
# 8                          1927.0
# 9                           726.0
# 10                          202.0
# 11                           49.0
# 12                           27.0
# 13                           30.0
# 14                           52.0
# 15                          200.0
# 16                          504.0
# 17                          557.0
# 18                          323.0
# 19                          262.0
# 20                          256.0
# 21                          132.0
# 22                           34.0
# 23                           29.0
# 24                           93.0
# 25                          123.0
# 26                          148.0
# 27                          122.0
# 28                          187.0
# 29                          684.0
# 30                          182.0
# 31                           43.0
# 32                           30.0
# 33                           48.0
# 34                           31.0
# 35                           42.0
# 36                           41.0
# 37                           32.0
# 38                           48.0
# 39                           45.0
# 40                           59.0
# 41                           65.0
# 42                           44.0
# 43                           19.0
# 44                           11.0
# 45                           15.0
# 46                           16.0

# %%
#KK

by_year_fdeaths = total_fcovid_deaths.loc[total_fcovid_deaths["Group"] == "By Year", columns2]
by_year_fdeaths ['Year'] = by_year_fdeaths ['Year'].astype(int)

by_year_fdeaths
# Out:
#    Start Date    End Date       State     Sex    Group Age Group  Year  Month  \
# 1  01/01/2020  12/31/2020  New Jersey  Female  By Year  All Ages  2020    0.0
# 2  01/01/2021  12/31/2021  New Jersey  Female  By Year  All Ages  2021    0.0
# 3  01/01/2022  12/31/2022  New Jersey  Female  By Year  All Ages  2022    0.0
# 4  01/01/2023  09/23/2023  New Jersey  Female  By Year  All Ages  2023    0.0
#
#    COVID-19 Deaths  Pneumonia Deaths  Pneumonia and COVID-19 Deaths
# 1           8283.0            5943.0                         3865.0
# 2           4265.0            3851.0                         2266.0
# 3           3081.0            2867.0                         1285.0
# 4            686.0            1358.0                          194.0

# %%
#KK

c2 = {'orange','red', 'green'} 
by_year_fdeaths.plot.bar(x='Year', y=['Pneumonia and COVID-19 Deaths','Pneumonia Deaths','COVID-19 Deaths'],
                                             figsize=(10,6), alpha=.8, color=c2, title ='Female Deaths in NJ')
plt.xlabel('Year')
plt.ylabel('# of Deaths')
plt.ylim(0,10000)
plt.savefig("Female Deaths.png")

# %%
#KK

all_deaths = pd.concat([by_year_fdeaths,by_year_mdeaths])
#ax = all_deaths.plot(kind='bar', x='Year', y=['Pneumonia and COVID-19 Deaths','Pneumonia Deaths','COVID-19 Deaths'])
all_deaths
# Out:
#    Start Date    End Date       State     Sex    Group Age Group  Year  Month  \
# 1  01/01/2020  12/31/2020  New Jersey  Female  By Year  All Ages  2020    0.0
# 2  01/01/2021  12/31/2021  New Jersey  Female  By Year  All Ages  2021    0.0
# 3  01/01/2022  12/31/2022  New Jersey  Female  By Year  All Ages  2022    0.0
# 4  01/01/2023  09/23/2023  New Jersey  Female  By Year  All Ages  2023    0.0
# 1  01/01/2020  12/31/2020  New Jersey    Male  By Year  All Ages  2020    0.0
# 2  01/01/2021  12/31/2021  New Jersey    Male  By Year  All Ages  2021    0.0
# 3  01/01/2022  12/31/2022  New Jersey    Male  By Year  All Ages  2022    0.0
# 4  01/01/2023  09/23/2023  New Jersey    Male  By Year  All Ages  2023    0.0
#
#    COVID-19 Deaths  Pneumonia Deaths  Pneumonia and COVID-19 Deaths
# 1           8283.0            5943.0                         3865.0
# 2           4265.0            3851.0                         2266.0
# 3           3081.0            2867.0                         1285.0
# 4            686.0            1358.0                          194.0
# 1           9881.0            7353.0                         4981.0
# 2           5340.0            4787.0                         2871.0
# 3           3490.0            3392.0                         1585.0
# 4            665.0            1480.0                          240.0

# %%
#KK

by_year_fdeaths['All Deaths']= by_year_fdeaths[['COVID-19 Deaths', 'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths']].sum(axis=1)
by_year_fdeaths
# Out:
#    Start Date    End Date       State     Sex    Group Age Group  Year  Month  \
# 1  01/01/2020  12/31/2020  New Jersey  Female  By Year  All Ages  2020    0.0
# 2  01/01/2021  12/31/2021  New Jersey  Female  By Year  All Ages  2021    0.0
# 3  01/01/2022  12/31/2022  New Jersey  Female  By Year  All Ages  2022    0.0
# 4  01/01/2023  09/23/2023  New Jersey  Female  By Year  All Ages  2023    0.0
#
#    COVID-19 Deaths  Pneumonia Deaths  Pneumonia and COVID-19 Deaths  \
# 1           8283.0            5943.0                         3865.0
# 2           4265.0            3851.0                         2266.0
# 3           3081.0            2867.0                         1285.0
# 4            686.0            1358.0                          194.0
#
#    All Deaths
# 1     18091.0
# 2     10382.0
# 3      7233.0
# 4      2238.0

# %%
#KK

all_fdeaths = by_year_fdeaths['All Deaths'].sum()
all_fdeaths
# Out:
# 37944.0

# %%
#KK

by_year_mdeaths['All Deaths']= by_year_mdeaths[['COVID-19 Deaths', 'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths']].sum(axis=1)
by_year_mdeaths
# Out:
#    Start Date    End Date       State   Sex    Group Age Group  Year  Month  \
# 1  01/01/2020  12/31/2020  New Jersey  Male  By Year  All Ages  2020    0.0
# 2  01/01/2021  12/31/2021  New Jersey  Male  By Year  All Ages  2021    0.0
# 3  01/01/2022  12/31/2022  New Jersey  Male  By Year  All Ages  2022    0.0
# 4  01/01/2023  09/23/2023  New Jersey  Male  By Year  All Ages  2023    0.0
#
#    COVID-19 Deaths  Pneumonia Deaths  Pneumonia and COVID-19 Deaths  \
# 1           9881.0            7353.0                         4981.0
# 2           5340.0            4787.0                         2871.0
# 3           3490.0            3392.0                         1585.0
# 4            665.0            1480.0                          240.0
#
#    All Deaths
# 1     22215.0
# 2     12998.0
# 3      8467.0
# 4      2385.0

# %%
#KK

all_mdeaths = by_year_mdeaths['All Deaths'].sum()
all_mdeaths
# Out:
# 46065.0

# %%
#KK

deaths = {'Sex': ['Male','Female'], 'Deaths': [all_mdeaths,all_fdeaths]}
all_fmdeaths = pd.DataFrame(deaths)
all_fmdeaths = all_fmdeaths.set_index(['Sex'])
all_fmdeaths ['Deaths'] = all_fmdeaths ['Deaths'].astype(int)
all_fmdeaths
# Out:
#         Deaths
# Sex
# Male     46065
# Female   37944

# %%
#KK

colors3= ['lightsteelblue','orange']
all_fmdeaths.plot(kind='pie', autopct='%1.1f%%', y='Deaths', title='Combined Deaths from 2020-2023 by Gender',
                  subplots=True, colors=colors3,shadow=True, legend='', label='')
plt.savefig("Percentage of Deaths.png")
