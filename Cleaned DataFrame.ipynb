# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
covid_data_csv = Path("COVID-19_Deaths_by_Sex_and_Age_20240328.csv")
covid_data_df = pd.read_csv(covid_data_csv)

# %%
covid_data_df.head()

covid_data_df.dropna(subset=["COVID-19 Deaths", "Total Deaths", "Pneumonia Deaths", "Pneumonia and COVID-19 Deaths"], inplace=True)

columns = ["Start Date", "End Date",	"Group", "Year", "Month", "State", "Sex", "Age Group",
           "COVID-19 Deaths", "Total Deaths", "Pneumonia Deaths", "Pneumonia and COVID-19 Deaths"]
covid_nj_df = covid_data_df.loc[covid_data_df["State"] == "New Jersey", columns]
covid_nj_df
# Out:
#        Start Date    End Date     Group    Year  Month       State        Sex  \
# 1581   01/01/2020  09/23/2023  By Total     NaN    NaN  New Jersey  All Sexes
# 1586   01/01/2020  09/23/2023  By Total     NaN    NaN  New Jersey  All Sexes
# 1587   01/01/2020  09/23/2023  By Total     NaN    NaN  New Jersey  All Sexes
# 1588   01/01/2020  09/23/2023  By Total     NaN    NaN  New Jersey  All Sexes
# 1589   01/01/2020  09/23/2023  By Total     NaN    NaN  New Jersey  All Sexes
# ...           ...         ...       ...     ...    ...         ...        ...
# 87181  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey       Male
# 87193  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey     Female
# 87197  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey     Female
# 87199  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey     Female
# 87200  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey     Female
#
# ...

# %%
covid_nj_df['Month'] = covid_nj_df['Month'].fillna(0)
covid_nj_df['Year'] = covid_nj_df['Year'].fillna(0)
covid_nj_df
# Out:
#        Start Date    End Date     Group    Year  Month       State        Sex  \
# 1581   01/01/2020  09/23/2023  By Total     0.0    0.0  New Jersey  All Sexes
# 1586   01/01/2020  09/23/2023  By Total     0.0    0.0  New Jersey  All Sexes
# 1587   01/01/2020  09/23/2023  By Total     0.0    0.0  New Jersey  All Sexes
# 1588   01/01/2020  09/23/2023  By Total     0.0    0.0  New Jersey  All Sexes
# 1589   01/01/2020  09/23/2023  By Total     0.0    0.0  New Jersey  All Sexes
# ...           ...         ...       ...     ...    ...         ...        ...
# 87181  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey       Male
# 87193  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey     Female
# 87197  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey     Female
# 87199  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey     Female
# 87200  09/01/2023  09/23/2023  By Month  2023.0    9.0  New Jersey     Female
#
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Data As Of, Start Date, End Date, Group, Year, Month, State, Sex, Age Group, COVID-19 Deaths, Total Deaths, Pneumonia Deaths, Pneumonia and COVID-19 Deaths, Influenza Deaths, Pneumonia, Influenza, or COVID-19 Deaths]
# Index: []
