# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
Cleaned_Covid_Data = Path('Cleaned_Covid_Data.csv')

# %%
Cleaned_Covid_Data
# Out:
# PosixPath('Cleaned_Covid_Data.csv')

# %%
Cleaned_Covid_Data = pd.read_csv(Cleaned_Covid_Data)

# %%
Cleaned_Covid_Data.head()
# Out:
#    Unnamed: 0  Data As Of  Start Date    End Date     Group  Year  Month  \
# 0           0  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
# 1           1  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
# 2           2  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
# 3           3  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
# 4           4  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0
#
#            State        Sex     Age Group  COVID-19 Deaths  Total Deaths  \
# 0  United States  All Sexes      All Ages        1146774.0    12303399.0
# 1  United States  All Sexes  Under 1 year            519.0       73213.0
# 2  United States  All Sexes    0-17 years           1696.0      130970.0
# 3  United States  All Sexes     1-4 years            285.0       14299.0
# 4  United States  All Sexes    5-14 years            509.0       22008.0
#
#    Pneumonia Deaths  Pneumonia and COVID-19 Deaths
# ...

# %%
Age_Tot_Deaths2 = Cleaned_Covid_Data[["Age Group", "State", "Total Deaths", "COVID-19 Deaths", "Year", "Start Date", "End Date", "Sex"]]

# %%
Age_Tot_Deaths2
# Out:
#           Age Group          State  Total Deaths  COVID-19 Deaths    Year  \
# 0          All Ages  United States    12303399.0        1146774.0     0.0
# 1      Under 1 year  United States       73213.0            519.0     0.0
# 2        0-17 years  United States      130970.0           1696.0     0.0
# 3         1-4 years  United States       14299.0            285.0     0.0
# 4        5-14 years  United States       22008.0            509.0     0.0
# ...             ...            ...           ...              ...     ...
# 54101    5-14 years    Puerto Rico           0.0              0.0  2023.0
# 54102      All Ages    Puerto Rico         664.0             15.0  2023.0
# 54103  Under 1 year    Puerto Rico           0.0              0.0  2023.0
# 54104    5-14 years    Puerto Rico           0.0              0.0  2023.0
# 54105   55-64 years    Puerto Rico          65.0              0.0  2023.0
#
#        Start Date    End Date        Sex
# ...

# %%
columns = ["Age Group", "State", "Total Deaths", "COVID-19 Deaths", "Year", "Start Date", "End Date", "Sex"]
US = Age_Tot_Deaths2.loc[Age_Tot_Deaths2["State"] == "United States", columns]
US
# Out:
#                Age Group          State  Total Deaths  COVID-19 Deaths  \
# 0               All Ages  United States    12303399.0        1146774.0
# 1           Under 1 year  United States       73213.0            519.0
# 2             0-17 years  United States      130970.0           1696.0
# 3              1-4 years  United States       14299.0            285.0
# 4             5-14 years  United States       22008.0            509.0
# ...                  ...            ...           ...              ...
# 10494        50-64 years  United States        6696.0            101.0
# 10495        55-64 years  United States        5363.0             85.0
# 10496        65-74 years  United States       10254.0            219.0
# 10497        75-84 years  United States       15911.0            391.0
# 10498  85 years and over  United States       22255.0            621.0
#
#          Year  Start Date    End Date        Sex
# 0         0.0  01/01/2020  09/23/2023  All Sexes
# ...

# %%
columns = ["Age Group", "State", "Total Deaths", "COVID-19 Deaths", "Year", "Start Date", "End Date", "Sex"]
NJ_df = Age_Tot_Deaths2.loc[Age_Tot_Deaths2["State"] == "New Jersey", columns]
NJ_df
# Out:
#          Age Group       State  Total Deaths  COVID-19 Deaths    Year  \
# 1149      All Ages  New Jersey      312963.0          35691.0     0.0
# 1150   15-24 years  New Jersey        2051.0             53.0     0.0
# 1151   18-29 years  New Jersey        4079.0            166.0     0.0
# 1152   25-34 years  New Jersey        5603.0            287.0     0.0
# 1153   30-39 years  New Jersey        7323.0            452.0     0.0
# ...            ...         ...           ...              ...     ...
# 36072  15-24 years  New Jersey          10.0              0.0  2023.0
# 36073     All Ages  New Jersey        1824.0             44.0  2023.0
# 36074   5-14 years  New Jersey           0.0              0.0  2023.0
# 36075  18-29 years  New Jersey          14.0              0.0  2023.0
# 36076  25-34 years  New Jersey          14.0              0.0  2023.0
#
#        Start Date    End Date        Sex
# 1149   01/01/2020  09/23/2023  All Sexes
# 1150   01/01/2020  09/23/2023  All Sexes
# ...

# %%
US_df_sd = US.loc[US["Start Date"] == "01/01/2020", columns]
US_df_sd
# Out:
#               Age Group          State  Total Deaths  COVID-19 Deaths    Year  \
# 0              All Ages  United States    12303399.0        1146774.0     0.0
# 1          Under 1 year  United States       73213.0            519.0     0.0
# 2            0-17 years  United States      130970.0           1696.0     0.0
# 3             1-4 years  United States       14299.0            285.0     0.0
# 4            5-14 years  United States       22008.0            509.0     0.0
# ...                 ...            ...           ...              ...     ...
# 8250        50-64 years  United States       16902.0              1.0  2020.0
# 8251        55-64 years  United States       13514.0              0.0  2020.0
# 8252        65-74 years  United States       22486.0              1.0  2020.0
# 8253        75-84 years  United States       30924.0              1.0  2020.0
# 8254  85 years and over  United States       50070.0              0.0  2020.0
#
# ...

# %%
NJ_df_sd = NJ_df.loc[NJ_df["Start Date"] == "01/01/2020", columns]
NJ_df_sd
# Out:
#                Age Group       State  Total Deaths  COVID-19 Deaths    Year  \
# 1149            All Ages  New Jersey      312963.0          35691.0     0.0
# 1150         15-24 years  New Jersey        2051.0             53.0     0.0
# 1151         18-29 years  New Jersey        4079.0            166.0     0.0
# 1152         25-34 years  New Jersey        5603.0            287.0     0.0
# 1153         30-39 years  New Jersey        7323.0            452.0     0.0
# ...                  ...         ...           ...              ...     ...
# 35149        18-29 years  New Jersey          23.0              0.0  2020.0
# 35150        50-64 years  New Jersey         372.0              0.0  2020.0
# 35151        65-74 years  New Jersey         529.0              0.0  2020.0
# 35152        75-84 years  New Jersey         867.0              0.0  2020.0
# 35153  85 years and over  New Jersey        1528.0              0.0  2020.0
#
#        Start Date    End Date        Sex
# ...

# %%
NJ_df_ed = NJ_df_sd.loc[NJ_df_sd["End Date"] == "09/23/2023", columns]
NJ_df_ed
# Out:
#               Age Group       State  Total Deaths  COVID-19 Deaths  Year  \
# 1149           All Ages  New Jersey      312963.0          35691.0   0.0
# 1150        15-24 years  New Jersey        2051.0             53.0   0.0
# 1151        18-29 years  New Jersey        4079.0            166.0   0.0
# 1152        25-34 years  New Jersey        5603.0            287.0   0.0
# 1153        30-39 years  New Jersey        7323.0            452.0   0.0
# 1154        35-44 years  New Jersey        8874.0            697.0   0.0
# 1155        40-49 years  New Jersey       11171.0           1105.0   0.0
# 1156        45-54 years  New Jersey       16508.0           1890.0   0.0
# 1157        50-64 years  New Jersey       47788.0           5849.0   0.0
# 1158        55-64 years  New Jersey       37609.0           4650.0   0.0
# 1159        65-74 years  New Jersey       57393.0           7320.0   0.0
# 1160        75-84 years  New Jersey       76960.0           9370.0   0.0
# ...

# %%
US_df_ed = US_df_sd.loc[US_df_sd["End Date"] == "09/23/2023", columns]
US_df_ed
# Out:
#             Age Group          State  Total Deaths  COVID-19 Deaths  Year  \
# 0            All Ages  United States    12303399.0        1146774.0   0.0
# 1        Under 1 year  United States       73213.0            519.0   0.0
# 2          0-17 years  United States      130970.0           1696.0   0.0
# 3           1-4 years  United States       14299.0            285.0   0.0
# 4          5-14 years  United States       22008.0            509.0   0.0
# 5         15-24 years  United States      133459.0           3021.0   0.0
# 6         18-29 years  United States      231382.0           7030.0   0.0
# 7         25-34 years  United States      278680.0          12401.0   0.0
# 8         30-39 years  United States      348041.0          19886.0   0.0
# 9         35-44 years  United States      416477.0          30108.0   0.0
# 10        40-49 years  United States      511478.0          46260.0   0.0
# 11        45-54 years  United States      709522.0          71388.0   0.0
# ...

# %%
NJ_df_full = NJ_df_ed.loc[NJ_df_sd["Sex"] == "All Sexes", columns]
NJ_df_full
# Out:
#               Age Group       State  Total Deaths  COVID-19 Deaths  Year  \
# 1149           All Ages  New Jersey      312963.0          35691.0   0.0
# 1150        15-24 years  New Jersey        2051.0             53.0   0.0
# 1151        18-29 years  New Jersey        4079.0            166.0   0.0
# 1152        25-34 years  New Jersey        5603.0            287.0   0.0
# 1153        30-39 years  New Jersey        7323.0            452.0   0.0
# 1154        35-44 years  New Jersey        8874.0            697.0   0.0
# 1155        40-49 years  New Jersey       11171.0           1105.0   0.0
# 1156        45-54 years  New Jersey       16508.0           1890.0   0.0
# 1157        50-64 years  New Jersey       47788.0           5849.0   0.0
# 1158        55-64 years  New Jersey       37609.0           4650.0   0.0
# 1159        65-74 years  New Jersey       57393.0           7320.0   0.0
# 1160        75-84 years  New Jersey       76960.0           9370.0   0.0
# ...

# %%
US_df_full = US_df_ed.loc[US_df_ed["Sex"] == "All Sexes", columns]
US_df_full
# Out:
#             Age Group          State  Total Deaths  COVID-19 Deaths  Year  \
# 0            All Ages  United States    12303399.0        1146774.0   0.0
# 1        Under 1 year  United States       73213.0            519.0   0.0
# 2          0-17 years  United States      130970.0           1696.0   0.0
# 3           1-4 years  United States       14299.0            285.0   0.0
# 4          5-14 years  United States       22008.0            509.0   0.0
# 5         15-24 years  United States      133459.0           3021.0   0.0
# 6         18-29 years  United States      231382.0           7030.0   0.0
# 7         25-34 years  United States      278680.0          12401.0   0.0
# 8         30-39 years  United States      348041.0          19886.0   0.0
# 9         35-44 years  United States      416477.0          30108.0   0.0
# 10        40-49 years  United States      511478.0          46260.0   0.0
# 11        45-54 years  United States      709522.0          71388.0   0.0
# ...

# %%
US_ages = US_df_full.drop([0, 1, 2, 3, 4, 6, 8, 10, 12]) 
US_ages
# Out:
#             Age Group          State  Total Deaths  COVID-19 Deaths  Year  \
# 5         15-24 years  United States      133459.0           3021.0   0.0
# 7         25-34 years  United States      278680.0          12401.0   0.0
# 9         35-44 years  United States      416477.0          30108.0   0.0
# 11        45-54 years  United States      709522.0          71388.0   0.0
# 13        55-64 years  United States     1604904.0         159712.0   0.0
# 14        65-74 years  United States     2509095.0         256806.0   0.0
# 15        75-84 years  United States     3034906.0         300162.0   0.0
# 16  85 years and over  United States     3506836.0         311863.0   0.0
#
#     Start Date    End Date        Sex
# 5   01/01/2020  09/23/2023  All Sexes
# 7   01/01/2020  09/23/2023  All Sexes
# 9   01/01/2020  09/23/2023  All Sexes
# 11  01/01/2020  09/23/2023  All Sexes
# 13  01/01/2020  09/23/2023  All Sexes
# 14  01/01/2020  09/23/2023  All Sexes
# ...

# %%
total_deaths_only = NJ_df_full.drop([1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161], axis=0)
total_deaths_only
# Out:
#      Age Group       State  Total Deaths  COVID-19 Deaths  Year  Start Date  \
# 1149  All Ages  New Jersey      312963.0          35691.0   0.0  01/01/2020
#
#         End Date        Sex
# 1149  09/23/2023  All Sexes

# %%
NJ_clean_ages = NJ_df_full.drop([1149, 1151, 1153, 1155, 1157], axis=0)
NJ_clean_ages
# Out:
#               Age Group       State  Total Deaths  COVID-19 Deaths  Year  \
# 1150        15-24 years  New Jersey        2051.0             53.0   0.0
# 1152        25-34 years  New Jersey        5603.0            287.0   0.0
# 1154        35-44 years  New Jersey        8874.0            697.0   0.0
# 1156        45-54 years  New Jersey       16508.0           1890.0   0.0
# 1158        55-64 years  New Jersey       37609.0           4650.0   0.0
# 1159        65-74 years  New Jersey       57393.0           7320.0   0.0
# 1160        75-84 years  New Jersey       76960.0           9370.0   0.0
# 1161  85 years and over  New Jersey      106314.0          11401.0   0.0
#
#       Start Date    End Date        Sex
# 1150  01/01/2020  09/23/2023  All Sexes
# 1152  01/01/2020  09/23/2023  All Sexes
# 1154  01/01/2020  09/23/2023  All Sexes
# 1156  01/01/2020  09/23/2023  All Sexes
# 1158  01/01/2020  09/23/2023  All Sexes
# 1159  01/01/2020  09/23/2023  All Sexes
# ...

# %%
total_deaths_only = ["Total Deaths", "COVID-19 Deaths"] 
total_deaths_only = [312963, 35691]
labels = ["New Jersey Total Deaths (2020-2023)", "New Jersey COVID-19 Deaths (2020-2023)"]
colors = ["yellow","green"]
explode = (0,0)
legend = 'Total Deaths vs. Covid Deaths'

# %%
plt.pie(total_deaths_only, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=300)

plt.axis("equal")
plt.show()

# %%
NJ_US = Age_Tot_Deaths2.loc[[0,1149],:]
NJ_US
# Out:
#      Age Group          State  Total Deaths  COVID-19 Deaths  Year  \
# 0     All Ages  United States    12303399.0        1146774.0   0.0
# 1149  All Ages     New Jersey      312963.0          35691.0   0.0
#
#       Start Date    End Date        Sex
# 0     01/01/2020  09/23/2023  All Sexes
# 1149  01/01/2020  09/23/2023  All Sexes

# %%
comp = ["US COVID Deaths", "NJ COVID Deaths"] 
comp = [1146774, 35691]
labels = ['United States Total COVID Deaths (2020-2023)', 'New Jersey Total COVID Deaths (2020-2023)']
colors = ["orange","purple"]
explode = (0,0)

# %%
plt.pie(comp, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=300)

plt.axis("equal")
plt.show()

# %%
#Total death rates overall and related to COVID-17 in the US and NJ overall are relatively the same. 
#In comparison there is a 7% difference in COVID deaths where NJ trends slightly higher.

# %%
NJ_clean_ages.plot(x="Age Group", y=["Total Deaths", "COVID-19 Deaths"],
                xlabel="NJ Age Group",
                ylabel="NJ Number of Deaths", kind="bar", stacked=True, 
                title="New Jersey Total Deaths vs. New Jersey Covid Deaths (2020-2023)",
                width = .7, colormap='Paired')

US_ages.plot(x="Age Group", y=["Total Deaths", "COVID-19 Deaths"],
            xlabel="US Age Group",
            ylabel="US Number of Deaths", kind="bar", stacked=True,
            title="United States Total Deaths vs. United States Covid Deaths (2020-2023)",
            width = .7, colormap="viridis")

plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

plt.show()

# %%
#When comparing death rates in the US and NJ the trend is similar across ages as well. With death rates rising the higher the age.

# %%
US_ages.plot(x="Age Group", y=["Total Deaths", "COVID-19 Deaths"],
                xlabel="US Age Group",
                ylabel="US Number of Deaths",
                title="United States Total Deaths vs. United States Covid Deaths (2020-2023)",
                figsize=(15,5))

plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

NJ_clean_ages.plot(x="Age Group", y=["Total Deaths", "COVID-19 Deaths"],
                   xlabel="NJ Age Group",
                   ylabel="NJ Number of Deaths", kind="line",
                   title="New Jersey Total Deaths vs. New Jersey Covid Deaths (2020-2023)",
                   figsize=(15,5))
plt.show()

# %%
#This chart shows how the rate and trend of rising death rates in the US overall is very similar to the death rates both 
#overall and with COVID in NJ. 
#Minor differences arise with New Jersey having a higher rate of deaths among the 85 and over group.

# %%
df3 = pd.concat([NJ_clean_ages.set_index("Age Group"), US_ages.set_index("Age Group")], axis=1)
display(df3)
# Out:
#                         State  Total Deaths  COVID-19 Deaths  Year  \
# Age Group
# 15-24 years        New Jersey        2051.0             53.0   0.0
# 25-34 years        New Jersey        5603.0            287.0   0.0
# 35-44 years        New Jersey        8874.0            697.0   0.0
# 45-54 years        New Jersey       16508.0           1890.0   0.0
# 55-64 years        New Jersey       37609.0           4650.0   0.0
# 65-74 years        New Jersey       57393.0           7320.0   0.0
# 75-84 years        New Jersey       76960.0           9370.0   0.0
# 85 years and over  New Jersey      106314.0          11401.0   0.0
#
#                    Start Date    End Date        Sex          State  \
# Age Group
# 15-24 years        01/01/2020  09/23/2023  All Sexes  United States
# 25-34 years        01/01/2020  09/23/2023  All Sexes  United States
# 35-44 years        01/01/2020  09/23/2023  All Sexes  United States
# ...

# %%
cleaned_df3 = df3.drop(["Year", "Start Date", "End Date", "Sex"], axis=1)
cleaned_df3
# Out:
#                         State  Total Deaths  COVID-19 Deaths          State  \
# Age Group
# 15-24 years        New Jersey        2051.0             53.0  United States
# 25-34 years        New Jersey        5603.0            287.0  United States
# 35-44 years        New Jersey        8874.0            697.0  United States
# 45-54 years        New Jersey       16508.0           1890.0  United States
# 55-64 years        New Jersey       37609.0           4650.0  United States
# 65-74 years        New Jersey       57393.0           7320.0  United States
# 75-84 years        New Jersey       76960.0           9370.0  United States
# 85 years and over  New Jersey      106314.0          11401.0  United States
#
#                    Total Deaths  COVID-19 Deaths
# Age Group
# 15-24 years            133459.0           3021.0
# 25-34 years            278680.0          12401.0
# 35-44 years            416477.0          30108.0
# 45-54 years            709522.0          71388.0
# ...

# %%
covid_data_csv = Path("Cleaned_Covid_Data.csv")
covid_data_df = pd.read_csv(covid_data_csv)

# %%
covid_data_df
# Out:
#        Unnamed: 0  Data As Of  Start Date    End Date     Group    Year  \
# 0               0  09/27/2023  01/01/2020  09/23/2023  By Total     0.0
# 1               1  09/27/2023  01/01/2020  09/23/2023  By Total     0.0
# 2               2  09/27/2023  01/01/2020  09/23/2023  By Total     0.0
# 3               3  09/27/2023  01/01/2020  09/23/2023  By Total     0.0
# 4               4  09/27/2023  01/01/2020  09/23/2023  By Total     0.0
# ...           ...         ...         ...         ...       ...     ...
# 54101      137670  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0
# 54102      137683  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0
# 54103      137684  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0
# 54104      137687  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0
# 54105      137696  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0
#
#        Month          State        Sex     Age Group  COVID-19 Deaths  \
# ...

# %%
final_data_df = covid_data_df.loc[:,['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
       'State', 'Sex', 'Age Group', 'COVID-19 Deaths', 'Total Deaths',
       'Pneumonia Deaths', 'Pneumonia and COVID-19 Deaths']]
final_data_df.head(50)
# Out:
#     Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 1   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 2   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 3   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 4   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 5   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 6   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 7   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 8   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 9   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 10  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# ...

# %%
us_df = final_data_df.loc[final_data_df["State"] == "United States", :]
us_df.head(50)
# Out:
#     Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 1   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 2   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 3   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 4   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 5   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 6   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 7   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 8   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 9   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 10  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# ...

# %%
us_all_sex_df = us_df.loc[us_df["Sex"] == "All Sexes",:]
us_all_sex_df.head(50)
# Out:
#       Data As Of  Start Date    End Date     Group    Year  Month  \
# 0     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 1     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 2     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 3     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 4     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 5     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 6     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 7     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 8     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 9     09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 10    09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 11    09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 12    09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# ...

# %%
us_all_sex_by_total_df = us_all_sex_df.loc[us_all_sex_df["Group"] == "By Total",:]
us_all_sex_by_total_df
# Out:
#     Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 1   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 2   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 3   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 4   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 5   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 6   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 7   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 8   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 9   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 10  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# ...

# %%
diseases = ['COVID-19 Deaths','Pneumonia Deaths', 'Pneumonia and \nCOVID-19 Deaths']

all_total = us_all_sex_by_total_df.loc[0,['COVID-19 Deaths', 'Pneumonia Deaths', 
                                  'Pneumonia and COVID-19 Deaths']]
all_total
# Out:
# COVID-19 Deaths                  1146774.0
# Pneumonia Deaths                 1162844.0
# Pneumonia and COVID-19 Deaths     569264.0
# Name: 0, dtype: object

# %%
plt.bar(diseases, all_total, color='purple',alpha=.3)
plt.xticks(rotation = 70, ha = 'right', rotation_mode = 'anchor')
plt.title('Full Term Total Deaths by Disease')
plt.xlabel('Condition')
plt.ylabel("Volume of Death's (Millions)")
plt.savefig("4Year_Death_By_Disease.png", bbox_inches = 'tight')
plt.show()

# %%
drop_total_age_df = us_all_sex_by_total_df.loc[1:16,:]
drop_total_age_df
# Out:
#     Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 1   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 2   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 3   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 4   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 5   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 6   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 7   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 8   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 9   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 10  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 11  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# ...

# %%
test_df = drop_total_age_df.loc[[1,3,4,5,7,9,11,13,14,15,16],:]
test_df
# Out:
#     Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 1   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 3   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 4   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 5   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 7   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 9   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 11  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 13  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 14  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 15  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 16  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
#
# ...

# %%
young_group_df = test_df.loc[1:7,:]
young_group_df
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 1  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 3  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 4  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 5  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 7  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
#
#          Sex     Age Group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 1  All Sexes  Under 1 year            519.0       73213.0            1056.0
# 3  All Sexes     1-4 years            285.0       14299.0             692.0
# 4  All Sexes    5-14 years            509.0       22008.0             818.0
# 5  All Sexes   15-24 years           3021.0      133459.0            3175.0
# 7  All Sexes   25-34 years          12401.0      278680.0           11706.0
#
#    Pneumonia and COVID-19 Deaths
# ...

# %%
young_ages = ['Under 1 year', '1-4 years', '5-14 years',
              '15-24 years', '25-34 years']

us_AllSex_Total_CovidDeaths_younger = young_group_df['COVID-19 Deaths']
us_AllSex_Total_PneumoniaDeaths_younger = young_group_df['Pneumonia Deaths']

x_axis = np.arange(len(young_ages))

plt.figure(figsize=(15,5))
plt.bar(x_axis, us_AllSex_Total_CovidDeaths_younger, .3, color='green', alpha=.5, label = 'Covid Deaths')
plt.bar(x_axis+.3, us_AllSex_Total_PneumoniaDeaths_younger, .3, label = 'Pneumonia Deaths')
plt.xticks(x_axis +.3/2, young_ages)
plt.xticks(rotation = 70, ha = 'right', rotation_mode = 'anchor')
plt.legend()
plt.title('Covid vs. Pneumonia Deaths by Decade (>1 - 34)')
plt.xlabel('Age Ranges')
plt.ylabel('Volume of Deaths')
plt.savefig("Covid_Pneumonia_Young_Deaths.png", bbox_inches = 'tight')
plt.show()

# %%
old_group_df = test_df.loc[9:16,:]
old_group_df
# Out:
#     Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 9   09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 11  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 13  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 14  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 15  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
# 16  09/27/2023  01/01/2020  09/23/2023  By Total   0.0    0.0  United States
#
#           Sex          Age Group  COVID-19 Deaths  Total Deaths  \
# 9   All Sexes        35-44 years          30108.0      416477.0
# 11  All Sexes        45-54 years          71388.0      709522.0
# 13  All Sexes        55-64 years         159712.0     1604904.0
# 14  All Sexes        65-74 years         256806.0     2509095.0
# 15  All Sexes        75-84 years         300162.0     3034906.0
# ...

# %%
old_ages = ['35-44 years', 
              '45-54 years','55-64 years', '65-74 years', 
              '75-84 years', '85 years and over']

us_AllSex_Total_CovidDeaths_older = old_group_df['COVID-19 Deaths']
us_AllSex_Total_PneumoniaDeaths_older = old_group_df['Pneumonia Deaths']

x_axis = np.arange(len(old_ages))

plt.figure(figsize=(15,5))
plt.bar(x_axis, us_AllSex_Total_CovidDeaths_older, .3, color = 'green', alpha = .5, label = 'Covid Deaths')
plt.bar(x_axis+.3, us_AllSex_Total_PneumoniaDeaths_older, .3, label = 'Pneumonia Deaths')
plt.xticks(x_axis +.3/2, old_ages)
plt.xticks(rotation = 70, ha = 'right', rotation_mode = 'anchor')
plt.legend()
plt.title('Covid vs. Pneumonia Deaths by Decade (35 - 85+)')
plt.xlabel('Age Ranges')
plt.ylabel('Volume of Deaths')
plt.savefig("Covid_Pneumonia_Older_Deaths.png", bbox_inches = 'tight')
plt.show()

# %%
us_all_sex_all_ages_df = us_all_sex_df.loc[us_all_sex_df['Age Group'] == 'All Ages',:]
us_all_sex_all_ages_df
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month  \
# 0      09/27/2023  01/01/2020  09/23/2023  By Total     0.0    0.0
# 1986   09/27/2023  01/01/2020  12/31/2020   By Year  2020.0    0.0
# 2037   09/27/2023  01/01/2021  12/31/2021   By Year  2021.0    0.0
# 2088   09/27/2023  01/01/2022  12/31/2022   By Year  2022.0    0.0
# 2139   09/27/2023  01/01/2023  09/23/2023   By Year  2023.0    0.0
# 8204   09/27/2023  01/01/2020  01/31/2020  By Month  2020.0    1.0
# 8255   09/27/2023  02/01/2020  02/29/2020  By Month  2020.0    2.0
# 8306   09/27/2023  03/01/2020  03/31/2020  By Month  2020.0    3.0
# 8357   09/27/2023  04/01/2020  04/30/2020  By Month  2020.0    4.0
# 8408   09/27/2023  05/01/2020  05/31/2020  By Month  2020.0    5.0
# 8459   09/27/2023  06/01/2020  06/30/2020  By Month  2020.0    6.0
# 8510   09/27/2023  07/01/2020  07/31/2020  By Month  2020.0    7.0
# 8561   09/27/2023  08/01/2020  08/31/2020  By Month  2020.0    8.0
# ...

# %%
us_all_sex_all_ages_by_year_df = us_all_sex_all_ages_df.loc[us_all_sex_all_ages_df['Group'] == 'By Year',:]
us_all_sex_all_ages_by_year_df
# Out:
#       Data As Of  Start Date    End Date    Group    Year  Month  \
# 1986  09/27/2023  01/01/2020  12/31/2020  By Year  2020.0    0.0
# 2037  09/27/2023  01/01/2021  12/31/2021  By Year  2021.0    0.0
# 2088  09/27/2023  01/01/2022  12/31/2022  By Year  2022.0    0.0
# 2139  09/27/2023  01/01/2023  09/23/2023  By Year  2023.0    0.0
#
#               State        Sex Age Group  COVID-19 Deaths  Total Deaths  \
# 1986  United States  All Sexes  All Ages         385666.0     3390039.0
# 2037  United States  All Sexes  All Ages         463263.0     3471767.0
# 2088  United States  All Sexes  All Ages         246161.0     3288942.0
# 2139  United States  All Sexes  All Ages          51684.0     2152651.0
#
#       Pneumonia Deaths  Pneumonia and COVID-19 Deaths
# 1986          352010.0                       180086.0
# 2037          412006.0                       259613.0
# 2088          267652.0                       110393.0
# 2139          131176.0                        19172.0

# %%
covid_death_by_year = us_all_sex_all_ages_by_year_df['COVID-19 Deaths']
covid_death_by_year
# Out:
# 1986    385666.0
# 2037    463263.0
# 2088    246161.0
# 2139     51684.0
# Name: COVID-19 Deaths, dtype: float64

# %%
pneumonia_death_by_year = us_all_sex_all_ages_by_year_df['Pneumonia Deaths']
pneumonia_death_by_year
# Out:
# 1986    352010.0
# 2037    412006.0
# 2088    267652.0
# 2139    131176.0
# Name: Pneumonia Deaths, dtype: float64

# %%
year = [2020,2021,2022,2023]

# %%
covid_line,=plt.plot(year,covid_death_by_year,label="Covid")
pneumonia_line,=plt.plot(year,pneumonia_death_by_year,label="Pneumonia")
plt.xticks(year,year)
plt.legend(handles = [covid_line,pneumonia_line])
plt.grid()
plt.title('Total Covid vs. Total Pneumonia Deaths 2020 - 2023')
plt.xlabel('Year')
plt.ylabel('Volume of Deaths')
plt.savefig("Yearly_Covid_versus_Pneumonia_Deaths.png", bbox_inches = 'tight')
plt.show()
